# %%
import pandas as pd 
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score

# %%
df = pd.read_pickle('rapm_input.pkl')
gk = pd.read_csv('top5_standard_24.csv')
player_mins = pd.read_csv('playermins.1724.csv')
# Out:
# /var/folders/qt/m1d2k3qd4_z368vlhrz0r7w80000gn/T/ipykernel_27171/1671704154.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   gk = pd.read_csv('top5_standard_24.csv')

# %%
gk['Min_Playing'] = pd.to_numeric(gk['Min_Playing'], errors='coerce')

gk_grouped = (gk
              .groupby(['Player', 'Url'], as_index=False)
              .agg(
                  Min_Playing = ('Min_Playing', 'sum'),
                   Pos = ('Pos', lambda x: ', '.join(sorted(x.dropna().astype(str).unique())))))

gk_players = gk_grouped.loc[gk_grouped['Pos'].str.contains('GK', na=False), 'Player'].tolist()
print(f"Goalkeeper players to remove: {gk_players}")

off_cols = [f"{p}_offense" for p in gk_players if f"{p}_offense" in df.columns]
def_cols = [f"{p}_defense" for p in gk_players if f"{p}_defense" in df.columns]
to_drop = off_cols + def_cols 
print(f"Columns to drop: {to_drop}")

df = df.drop(columns=to_drop, errors='ignore')
# Out:
# Goalkeeper players to remove: ['Aaron Ramsdale', 'Aarón Escandell', 'Abdoulaye Diallo', 'Adrian Rodriguez', 'Adrian Šemper', 'Adrián', 'Agustín Marchesín', 'Aitor Fernández', 'Alaa Bellaarouch', 'Alban Lafont', 'Albano Bizzarri', 'Alberto Brignoli', 'Alberto Cifuentes', 'Alberto García', 'Alberto Paleari', 'Alejandro Primo', 'Aleksandar Jovanović', 'Alen Sherri', 'Alessandro Berardi', 'Alessandro Russo', 'Alessandro Sorrentino', 'Alessio Cragno', 'Alex Cordaz', 'Alex McCarthy', 'Alex Meret', 'Alex Padilla', 'Alex Palmer', 'Alexander Brunst', 'Alexander Meyer', 'Alexander Nübel', 'Alexander Schwolow', 'Alexandre Letellier', 'Alexandre Olliero', 'Alexandre Oukidja', 'Alfred Gomis', 'Alisson', 'Alphonse Areola', 'Altay Bayındır', 'Andrea Consigli', 'Andrea Seculin', 'Andreas Linde', 'Andreas Luthe', 'Andrey Lunyov', 'Andriy Lunin', 'André Ferreira', 'André Onana', 'Andrés Fernández', 'Andrés Prieto', 'Angelo da Costa Júnior', 'Angus Gunn', 'Anthony Lopes', 'Anthony Mandrea', 'Anthony Racioppi', 'Antonio Adán', 'Antonio Gomis', 'Antonio Mirante', 'Antonio Rosati', 'Antonio Santurro', 'Antonio Sivera', 'Antonín Kinský', 'Arijanet Muric', 'Arnau Rafús', 'Arnau Tenas', 'Arthur Desmas', 'Artur Boruc', 'Asier Riesgo', 'Asmir Begović', 'Augusto Batalla', 'Axel Werner', 'Bailey Peacock-Farrell', 'Baptiste Reynet', 'Bart Verbruggen', 'Bartłomiej Drągowski', 'Ben Foster', 'Ben Hamer', 'Benjamin Lecomte', 'Benjamin Leroy', 'Benjamin Uphoff', 'Benoît Costil', 'Bernd Leno', 'Bingourou Kamara', 'Boaz Myhill', 'Bobby Allain', 'Boris Radunović', 'Brandon Austin', 'Brice Samba', 'Caoimhín Kelleher', 'Carlo Pinsoglio', 'Christian Früchtl', 'Christian Mathenia', 'Christian Puggioni', 'Christian Walton', 'Christ
# Columns to drop: ['Aaron Ramsdale_offense', 'Aarón Escandell_offense', 'Abdoulaye Diallo_offense', 'Adrian Šemper_offense', 'Adrián_offense', 'Agustín Marchesín_offense', 'Aitor Fernández_offense', 'Alaa Bellaarouch_offense', 'Alban Lafont_offense', 'Albano Bizzarri_offense', 'Alberto Brignoli_offense', 'Alberto Cifuentes_offense', 'Alberto García_offense', 'Alberto Paleari_offense', 'Alejandro Primo_offense', 'Aleksandar Jovanović_offense', 'Alessandro Berardi_offense', 'Alessandro Russo_offense', 'Alessandro Sorrentino_offense', 'Alessio Cragno_offense', 'Alex Cordaz_offense', 'Alex McCarthy_offense', 'Alex Meret_offense', 'Alexander Brunst_offense', 'Alexander Meyer_offense', 'Alexander Nübel_offense', 'Alexander Schwolow_offense', 'Alexandre Letellier_offense', 'Alexandre Olliero_offense', 'Alexandre Oukidja_offense', 'Alfred Gomis_offense', 'Alisson_offense', 'Alphonse Areola_offense', 'Andrea Consigli_offense', 'Andrea Seculin_offense', 'Andreas Linde_offense', 'Andreas Luthe_offense', 'Andrey Lunyov_offense', 'Andriy Lunin_offense', 'André Ferreira_offense', 'André Onana_offense', 'Andrés Fernández_offense', 'Andrés Prieto_offense', 'Angelo da Costa Júnior_offense', 'Angus Gunn_offense', 'Anthony Lopes_offense', 'Anthony Mandrea_offense', 'Anthony Racioppi_offense', 'Antonio Adán_offense', 'Antonio Gomis_offense', 'Antonio Mirante_offense', 'Antonio Rosati_offense', 'Antonio Santurro_offense', 'Antonio Sivera_offense', 'Arijanet Muric_offense', 'Arnau Tenas_offense', 'Arthur Desmas_offense', 'Artur Boruc_offense', 'Asier Riesgo_offense', 'Asmir Begović_offense', 'Augusto Batalla_offense', 'Axel Werner_offense', 'Bailey Peacock-Farrell_offense', 'Baptiste Reynet_offense', 'Bart Verbruggen_offense', 'Bartłomiej Drągowski_offense', 'Ben Foster_offense', 'Ben Hamer_offense', 'Benjamin Lecomte_offense', 'Benjamin Leroy_offense', 'Benjamin Uphoff_offense', 'Benoît Costil_offense', 'Bernd Leno_offense', 'Bingourou Kamara_offense', 'Boaz Myhill_offense', 'Bobby Allain_offense', 'Boris Radunović_offense', 'Brice Samba_offense', 'Caoimhín Kelleher_offense', 'Carlo Pinsoglio_offense', 'Christian Früchtl_offense', 'Christian Mathenia_offense', 'Christian Puggioni_offense', 'Christos Mandas_offense', 'Churripi_offense', 'Ciprian Tătărușanu_offense', 'Claudio Bravo_offense', 'Costel Pantilimon_offense', 'Cristian_offense', 'Cárdenas_offense', 'Dani Giménez_offense', 'Daniel Bachmann_offense', 'Daniel Batz_offense', 'Daniel Bentley_offense', 'Daniel Fuzato_offense', 'Daniel Iversen_offense', 'Daniel Martín_offense', 'Daniel Peretz_offense', 'Daniele Padelli_offense', 'Daniele Sommariva_offense', 'Danijel Petković_offense', 'Danijel Subašić_offense', 'Danny Ward_offense', 'Darren Randolph_offense', 'David Button_offense', 'David Gil_offense', 'David Martin_offense', 'David Ospina_offense', 'David Raya_offense', 'David Soria_offense', 'David de Gea_offense', 'Davide Marfella_offense', 'Dean Henderson_offense', 'Demba Thiam_offense', 'Denis Petrić_offense', 'Dennis Smarsch_offense', 'Diant Ramaj_offense', 'Diego Benaglio_offense', 'Diego Conde_offense', 'Diego López_offense', 'Diego Mariño_offense', 'Dimitry Bertaud_offense', 'Dominik Greif_offense', 'Donovan Léon_offense', 'Doğan Alemdar_offense', 'Ederson_offense', 'Edouard Mendy_offense', 'Eiji Kawashima_offense', 'Eldin Jakupović_offense', 'Elia Caprile_offense', 'Elias Bördner_offense', 'Emil Audero_offense', 'Emiliano Martínez_offense', 'Emiliano Viviano_offense', 'Enrico Alfonso_offense', 'Erwin Zelazny_offense', 'Etienne Green_offense', 'Etrit Berisha_offense', 'Eugenio Lamanna_offense', 'Fabian Bredlow_offense', 'Fabian Giefer_offense', 'Fabricio_offense', 'Federico Brancolini_offense', 'Federico Marchetti_offense', 'Federico Ravaglia_offense', 'Felix Wiedwald_offense', 'Fernando_offense', 'Fernando Pacheco_offense', 'Filip Jørgensen_offense', 'Finn Dahmen_offense', 'Florian Kastenmeier_offense', 'Florian Müller_offense', 'Fran Vieites_offense', 'Francesco Bardi_offense', 'Franc ...

# %%
threshold = 2000 
replacement_players = set(player_mins.loc[player_mins['Min_Playing'] < threshold, 'Player']
)
print(f"Found {len(replacement_players)} replacement-level players")

off_cols = [f"{p}_offense" for p in replacement_players if f"{p}_offense" in df.columns]
def_cols = [f"{p}_defense" for p in replacement_players if f"{p}_defense" in df.columns]

df['replacement_offense'] = (df[off_cols] == 1).any(axis=1).astype(int)
df['replacement_defense'] = (df[def_cols] == 1).any(axis=1).astype(int)

df = df.drop(columns=off_cols + def_cols)
# Out:
# Found 3638 replacement-level players

# %%
df['xG_per_90'] = (df['total_xG'] / df['minutes_played']) * 90

# %%
feature_cols = [col for col in df.columns if col.endswith('_offense') or col.endswith('_defense')]

X = csr_matrix(df[feature_cols].values)
y = df['xG_per_90'].values

# %%
mask = np.isfinite(y)

X_clean = X[mask]
y_clean = y[mask]

# %%
model = Ridge(alpha=2000, solver='sparse_cg', max_iter=10000, tol=1e-3)
model.fit(X_clean, y_clean)
# Out:
# Ridge(alpha=2000, max_iter=10000, solver='sparse_cg', tol=0.001)

# %%
coef_series = pd.Series(model.coef_, index=feature_cols)

coef_df = coef_series.reset_index()
coef_df.columns = ['feature', 'coefficient']

coef_df[['player_name', 'offense_or_defense']] = (
    coef_df['feature'].str.rsplit(pat='_', n=1, expand=True)
)

coef_df = coef_df[['player_name', 'offense_or_defense', 'coefficient']]

wide = coef_df.pivot(
    index='player_name',
    columns='offense_or_defense',
    values='coefficient'
).reset_index()

wide[['offense','defense']] = wide[['offense','defense']].fillna(0)

wide['net'] = wide['offense'] - wide['defense']

wide = wide[['player_name', 'offense', 'defense', 'net']]

print(wide.sort_values('net', ascending=False).head(10))
# Out:
# offense_or_defense         player_name   offense   defense       net
# 2588                Robert Lewandowski  0.361335 -0.142414  0.503748
# 1684                     Kylian Mbappé  0.426097 -0.037718  0.463815
# 3033                   Virgil van Dijk  0.311477 -0.147900  0.459377
# 2759                      Serge Gnabry  0.391004 -0.051533  0.442537
# 205                   Andrew Robertson  0.214139 -0.220923  0.435062
# 1736                        Leroy Sané  0.276371 -0.156439  0.432811
# 1044                      Gerard Piqué  0.312873 -0.114306  0.427178
# 1485                    Joshua Kimmich  0.250162 -0.168708  0.418870
# 2170                     Mohamed Salah  0.245528 -0.162247  0.407774
# 3206                    İlkay Gündoğan  0.291305 -0.113863  0.405168
